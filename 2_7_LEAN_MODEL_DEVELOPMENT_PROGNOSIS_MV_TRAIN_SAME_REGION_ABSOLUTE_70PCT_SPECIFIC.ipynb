# %% [markdown]
# # 2) IACOV - Model Development for Prognosis - MV
# ## Strategy 7) Training on 70% of a specific hospital plus same absolute number of same region hospitals

# %%
# !pip install npm nodejs

# %%
# !jupyter lab clean
# !jupyter lab build

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# para evitarmos a exibição dos dados em notacao científica
pd.set_option('display.float_format', lambda x: '%.3f' % x)

#comment next line to not use MLFlow for cleaning data
from MLFlow_Classification import *
from MLFlow_Utils import *
# Out:
# C:\Users\carin\AppData\Local\Temp\ipykernel_13948\2017038996.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### This code uses just 14 hospitals, since ICU or MV has no variation for 4 hospitals
# #### - The code that prepares the data to run all strategies for ICU and MV is: PREPARING_DATA_TO_UCI_MV_ANALYSES
# #### - df_iacov_en.csv (used for death) was replaced here by df_iacov_model_lean_14hosp.csv
# #### - put df_iacov_model_lean_14hosp.csv in same folder as this notebook

# %%
#Put csv in same folder as this notebook
dataset = pd.read_csv("df_iacov_model_lean_14hosp.csv", delimiter=";")
df_iacov_model = pd.DataFrame(dataset)
df_iacov_model.shape
# Out:
# (6046, 30)

# %%
df_iacov_model.columns
# Out:
# Index(['city_hospital', 'age', 'male', 'race', 'heart_rate', 'resp_rate',
#        'sys_press', 'dias_press', 'mean_press', 'temp', 'hemoglobin',
#        'platelets', 'hematocrit', 'red_cells_count', 'hcm', 'rdw', 'mcv',
#        'leukocytes', 'neutrophil', 'lymphocytes', 'basophils', 'eosinophils',
#        'monocytes', 'crp', 'death', 'icu', 'mv', 'state', 'region', 'excluir'],
#       dtype='object')

# %% [markdown]
# ## 2.1) Assign binary outcome to be predicted

# %% [markdown]
# ### 2.1.1) Maintain essential variables (LEAN Model)

# %%
#22 predictors + outcome + Region/State
df_iacov_model_lean = df_iacov_model[['city_hospital'
                                      ,'age'
                                      ,'male'
                                      ,'heart_rate'
                                      ,'resp_rate'
                                      ,'sys_press'
                                      ,'dias_press'
                                      ,'mean_press'
                                      ,'temp'
                                      ,'hemoglobin'
                                      ,'platelets'
                                      ,'hematocrit'
                                      ,'red_cells_count'
                                      ,'hcm'
                                      ,'rdw'
                                      ,'mcv'
                                      ,'leukocytes'
                                      ,'neutrophil'
                                      ,'lymphocytes'
                                      ,'basophils'
                                      ,'eosinophils'
                                      ,'monocytes'
                                      ,'crp'
                                      ,'mv'
                                      ,'region' #for filtering purposes
                                      ,'state' #for filtering purposes
                                     ]]
df_iacov_model_lean.shape
# Out:
# (6046, 26)

# %%
df_iacov_model_lean.city_hospital.value_counts()
# Out:
# city_hospital
# HC_USP                        1500
# HOSPPORTUGUES_SALVADOR        1359
# CEARA_UNIMED                   845
# HRL_2021_02                    539
# HMV_POA_02                     456
# RIO_DE_JANEIRO_UNIMED          449
# HOSPSANTAJULIA_MANAUS          247
# HOSPSANTACATARINABLUMENAU      148
# HOSPSAOFRANCISCO_MOGIGUACU     124
# PERNAMBUCO_FULL                112
# PELOTAS                         91
# CEARA_HUWC                      73
# HEVV                            56
# AMAZONAS_HUGV                   47
# Name: count, dtype: int64

# %%
df_iacov_model_lean.to_csv('df_iacov_model_lean.csv', sep=';', index=False)

# %% [markdown]
# ### 2.1.2) Filter a specific hospital

# %%
#Put csv in same folder as this notebook
df_all_hospitals = pd.read_csv("df_iacov_model_lean.csv", delimiter=";", decimal=".")
df_all_hospitals.shape
# Out:
# (6046, 26)

# %%
df_all_hospitals.columns
# Out:
# Index(['city_hospital', 'age', 'male', 'heart_rate', 'resp_rate', 'sys_press',
#        'dias_press', 'mean_press', 'temp', 'hemoglobin', 'platelets',
#        'hematocrit', 'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes',
#        'neutrophil', 'lymphocytes', 'basophils', 'eosinophils', 'monocytes',
#        'crp', 'mv', 'region', 'state'],
#       dtype='object')

# %%
df_all_hospitals.region.value_counts()
# Out:
# region
# NORDESTE       2389
# SUDESTE        2129
# SUL             695
# CENTROOESTE     539
# NORTE           294
# Name: count, dtype: int64

# %%
column_summaries(df_all_hospitals)
# Out:
#                  Missing Values  % missing of Total Values  # Unique Values  \
# city_hospital                 0                      0.000               14
# age                           0                      0.000               98
# male                          0                      0.000                2
# heart_rate                  809                     13.381              183
# resp_rate                  1457                     24.099               69
# sys_press                  1336                     22.097              215
# dias_press                 1325                     21.915              150
# mean_press                 1366                     22.593             1452
# temp                       1173                     19.401              128
# hemoglobin                 1904                     31.492              226
# platelets                   744                     12.306             1036
# hematocrit                 2350                     38.869              475
# red_cells_count            2684                     44.393              578
# hcm                        1191                     19.699              689
# rdw                        1192                     19.716              227
# mcv                        1185                     19.600             1029
# leukocytes                  741                     12.256             2268
# neutrophil                 2074                     34.304             2403
# lymphocytes                1404                     23.222             1865
# basophils                  1120                     18.525              252
# eosinophils                2367                     39.150              495
# monocytes                   841                     13.910             1450
# crp                        1383                     22.875             2986
# mv                            0                      0.000                2
# region                        0                      0.000                5
# state                         0                      0.000               10
#
#                  # Values as [0] datatype   skew    count       mean  \
# city_hospital                  0   object    NaN      NaN        NaN
# age                            0  float64 -0.060 6046.000     57.521
# male                        2790  float64 -0.155 6046.000      0.539
# heart_rate                     0  float64  0.611 5237.000     85.689
# resp_rate                      1  float64  2.897 4589.000     21.881
# sys_press                      0  float64 -0.279 4710.000    124.054
# dias_press                     0  float64 -0.361 4721.000     74.608
# mean_press                   326  float64 -1.751 4680.000     83.731
# temp                           1  float64 62.972 4873.000     36.430
# hemoglobin                     0  float64 -0.628 4142.000     12.752
# platelets                      0  float64  0.395 5302.000 235701.617
# hematocrit                     0  float64 -0.539 3696.000     38.436
# red_cells_count                0  float64 -0.274 3362.000      3.915
# hcm                            0  float64  3.528 4855.000     29.095
# rdw                            0  float64 11.869 4854.000     13.837
# mcv                            0  float64  0.227 4861.000     87.665
# leukocytes                     0  float64 20.605 5305.000   7035.747
# neutrophil                     3  float64  1.830 3972.000   6143.968
# lymphocytes                    5  float64 15.570 4642.000   1031.263
# basophils                   2087  float64  5.342 4926.000      7.509
# eosinophils                 1487  float64 14.977 3679.000     43.517
# monocytes                     14  float64  2.534 5205.000    354.765
# crp                            0  float64  3.137 4663.000     36.696
# mv                          4343    int64  0.971 6046.000      0.282
# region                         0   object    NaN      NaN        NaN
# state                          0   object    NaN      NaN        NaN
#
#                        std    min        25%        50%        75%        max
# city_hospital          NaN    NaN        NaN        NaN        NaN        NaN
# age                 17.869 18.000     44.000     58.000     71.000    105.000
# male                 0.499  0.000      0.000      1.000      1.000      1.000
# heart_rate          17.209 13.000     75.000     85.000     96.000    233.000
# resp_rate            6.380  0.000     18.000     20.000     24.000    108.000
# sys_press           22.791 10.000    110.000    122.000    138.000    242.000
# dias_press          14.626  6.000     67.000     76.000     81.000    141.000
# mean_press          28.475  0.000     78.981     90.000     98.648    166.000
# temp                 4.976  0.000     36.000     36.300     36.800    372.000
# hemoglobin           2.189  1.400     11.692     13.000     14.200     30.600
# platelets       143771.202  7.000 148000.000 217000.000 321750.000 992000.000
# hematocrit           6.402  1.000     35.100     39.200     42.500     77.000
# red_cells_count      1.168  0.290      3.250      4.210      4.717     14.500
# hcm                  2.939 10.000     27.800     29.200     30.500     88.100
# rdw                  2.407  3.000     12.700     13.500     14.400     86.100
# mcv                  7.667  8.150     83.700     87.600     91.600    201.400
# leukocytes        9241.209  0.760   3680.000   6210.000   9233.000 365920.000
# neutrophil        4259.737  0.000   3180.000   5200.000   8060.000  47636.000
# lymphocytes       1028.587  0.000    529.250    900.000   1378.250  42120.000
# basophils           18.532  0.000      0.000      0.010     10.000    259.200
# eosinophils        127.479  0.000      0.000      1.000     46.000   4450.000
# monocytes          375.844  0.000      0.930    310.000    584.000   7243.000
# crp                 71.738  0.015      1.911      7.800     28.100    708.300
# mv                   0.450  0.000      0.000      0.000      1.000      1.000
# region                 NaN    NaN        NaN        NaN        NaN        NaN
# state                  NaN    NaN        NaN        NaN        NaN        NaN

# %%
import ipywidgets as widgets
from IPython.display import clear_output

# %%
df_all_hospitals.city_hospital.value_counts()
# Out:
# city_hospital
# HC_USP                        1500
# HOSPPORTUGUES_SALVADOR        1359
# CEARA_UNIMED                   845
# HRL_2021_02                    539
# HMV_POA_02                     456
# RIO_DE_JANEIRO_UNIMED          449
# HOSPSANTAJULIA_MANAUS          247
# HOSPSANTACATARINABLUMENAU      148
# HOSPSAOFRANCISCO_MOGIGUACU     124
# PERNAMBUCO_FULL                112
# PELOTAS                         91
# CEARA_HUWC                      73
# HEVV                            56
# AMAZONAS_HUGV                   47
# Name: count, dtype: int64

# %%
# Hospitals excluded for ICU and MV analyses: 'HOSPSANTACASASP_FULL', 'HOSPGRUPOSANTA', 'HUTRIN_2021_02', 'RIO_DE_JANEIRO_HUCFF'
dropdown_hospital = widgets.Dropdown(options = ['Choose a hospital ...'
                                                ,'HC_USP'                     #SP
                                                ,'HOSPPORTUGUES_SALVADOR'     #BA
                                                ,'CEARA_UNIMED'               #CE
                                                ,'HRL_2021_02'                #GO - Luiziania
                                                ,'HMV_POA_02'                 #RS - Moinhos de Vento
                                                ,'RIO_DE_JANEIRO_UNIMED'      #RJ
                                                ,'HOSPSANTAJULIA_MANAUS'      #AM
                                                ,'HOSPSANTACATARINABLUMENAU'  #SC
                                                ,'HOSPSAOFRANCISCO_MOGIGUACU' #SP
                                                ,'PERNAMBUCO_FULL'            #PE
                                                ,'PELOTAS'                    #RS
                                                ,'CEARA_HUWC'                 #CE
                                                ,'HEVV'                       #ES - Vila Velha
                                                ,'AMAZONAS_HUGV'              #AM
#                                                 ,'GHC_02'                     #RS 
                                               ])

# %%
specific_hospital = 'Choose a hospital'
df_iacov_model_lean = df_all_hospitals

def dropdown_hospital_eventhandler(change):
    global specific_hospital 
    specific_hospital = change.new
    dropdown_hospital.observe(dropdown_hospital_eventhandler, names='value')

# %%
dropdown_hospital.observe(dropdown_hospital_eventhandler, names='value')

# %% [markdown]
# **Select Hospital to train**

# %%
# !pip install ipywidgets

# %%
# !jupyter nbextension enable --py widgetsnbextension

# %%
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager

# %%
display(dropdown_hospital)
# Out:
# Dropdown(index=12, options=('Choose a hospital ...', 'HC_USP', 'HOSPPORTUGUES_SALVADOR', 'CEARA_UNIMED', 'HRL_…

# %% [markdown]
# **Filter all hospitals except the selected above**

# %%
df_all_hospitals.region.value_counts()
# Out:
# region
# NORDESTE       2389
# SUDESTE        2129
# SUL             695
# CENTROOESTE     539
# NORTE           294
# Name: count, dtype: int64

# %% [markdown]
# **Split train/test of specific Hospital**

# %%
from sklearn.model_selection import train_test_split

# %%
#Filter the specific hospital
df_iacov_model_lean_specific = df_all_hospitals[df_all_hospitals.city_hospital == specific_hospital]
df_iacov_model_lean_specific.shape
# Out:
# (73, 26)

# %%
X_specific = df_iacov_model_lean_specific.drop(['mv'],axis=1)
X_specific.shape
# Out:
# (73, 25)

# %%
y_specific = df_iacov_model_lean_specific['mv']
y_specific.shape
# Out:
# (73,)

# %%
X_train_specific, X_test_specific, y_train_specific, y_test_specific = train_test_split(X_specific, y_specific, test_size=0.30, random_state=42, stratify=y_specific)

# %%
X_train_specific.shape
# Out:
# (51, 25)

# %%
X_test_specific.shape
# Out:
# (22, 25)

# %% [markdown]
# **Filter same absolute number from hospitals on same region**
#
# PS: Also removed GHC hospital due to very low positive cases

# %%
from random import sample

#Sample all hospitals except specific hospital
df_all_hospitals_except_specific = df_all_hospitals[ (~df_all_hospitals.index.isin(X_specific.index)) &
                                                       (df_all_hospitals.city_hospital != 'GHC_02')]

#Sample all hospitals of same region of specific hospital
df_all_hospitals_same_region = df_all_hospitals_except_specific[df_all_hospitals_except_specific.region == X_specific.region.iloc[0]]

#Then, sample all hospital data with same absolute number on same region as specific hospital
df_iacov_model_lean = df_all_hospitals_same_region.sample(X_train_specific.shape[0], random_state=42, replace=True)
df_iacov_model_lean.shape
# Out:
# (51, 26)

# %% [markdown]
# If error Cannot take a larger sample than population when 'replace=False', use resample with replace

# %%
# #Then, sample all hospital data with same absolute number on same region as specific hospital
# df_iacov_model_lean = df_all_hospitals_same_region.sample(X_train_specific.shape[0], random_state=42, replace=True)
# df_iacov_model_lean.shape

# %%
#Check data from same region
df_iacov_model_lean.city_hospital.value_counts()
# Out:
# city_hospital
# HOSPPORTUGUES_SALVADOR    33
# CEARA_UNIMED              15
# PERNAMBUCO_FULL            3
# Name: count, dtype: int64

# %% [markdown]
# **Append 70% data of specific hospital**

# %%
df_iacov_model_lean = pd.concat([df_iacov_model_lean, X_train_specific], axis=0)
df_iacov_model_lean.shape
# Out:
# (102, 26)

# %%
#Check after apending data of specific hospital
df_iacov_model_lean.city_hospital.value_counts()
# Out:
# city_hospital
# CEARA_HUWC                51
# HOSPPORTUGUES_SALVADOR    33
# CEARA_UNIMED              15
# PERNAMBUCO_FULL            3
# Name: count, dtype: int64

# %%
print("Specific: " + specific_hospital )
print("(training - same regions - same absolute number) dataset: " + str(df_iacov_model_lean.shape))

print("\n(training - specific) dataset: {}".format(X_train_specific.shape))

print("\n(test - specific) dataset: {}".format(X_test_specific.shape))
# Out:
# Specific: CEARA_HUWC
# (training - same regions - same absolute number) dataset: (102, 26)
#
# (training - specific) dataset: (51, 25)
#
# (test - specific) dataset: (22, 25)

# %% [markdown]
# ### 2.1.3) Dropping unused variables (All hospitals)

# %%
df_iacov_model_lean = df_iacov_model_lean.drop(['city_hospital'],axis=1)
df_iacov_model_lean.shape
# Out:
# (102, 25)

# %%
#Preencho NAs com 0 
df_iacov_model_lean['mv'] = df_iacov_model_lean['mv'].fillna(0)
df_iacov_model_lean.mv.value_counts()
# Out:
# mv
# 0.000    95
# 1.000     7
# Name: count, dtype: int64

# %%
(df_iacov_model_lean.mv.value_counts()/len(df_iacov_model_lean.mv))*100
# Out:
# mv
# 0.000   93.137
# 1.000    6.863
# Name: count, dtype: float64

# %% [markdown]
# ### From now on the outcome will call CLASS

# %%
df_iacov_model_lean['class'] = df_iacov_model_lean['mv'].astype('int')
df_iacov_model_lean = df_iacov_model_lean.drop(['mv'],axis=1)

# %% [markdown]
# ### 2.1.4) Recalculating null mean_press

# %%
def isNullMeanPressure(row):

    if pd.isnull(row['mean_press']):
    
        if pd.notnull(row['sys_press']) and pd.notnull(row['dias_press']):
            return (row['sys_press']+row['dias_press'])/2
        else:
            return row['mean_press']
    else:
        return row['mean_press']

# %%
#Check mean_press missing before recalculating
column_summaries(df_iacov_model_lean)
# Out:
#                  Missing Values  % missing of Total Values  # Unique Values  \
# age                           0                      0.000               54
# male                          0                      0.000                2
# heart_rate                    7                      6.863               51
# resp_rate                    22                     21.569               16
# sys_press                    21                     20.588               49
# dias_press                   21                     20.588               44
# mean_press                   24                     23.529               48
# temp                         17                     16.667               34
# hemoglobin                   10                      9.804               62
# platelets                    10                      9.804               90
# hematocrit                   10                      9.804               83
# red_cells_count              10                      9.804               77
# hcm                          11                     10.784               57
# rdw                          11                     10.784               48
# mcv                          11                     10.784               77
# leukocytes                   10                      9.804               91
# neutrophil                   19                     18.627               81
# lymphocytes                  19                     18.627               79
# basophils                    11                     10.784               39
# eosinophils                  10                      9.804               59
# monocytes                    12                     11.765               84
# crp                          19                     18.627               81
# region                        0                      0.000                1
# state                         0                      0.000                3
# class                         0                      0.000                2
#
#                  # Values as [0] datatype   skew   count       mean  \
# age                            0  float64  0.072 102.000     53.951
# male                          45  float64 -0.240 102.000      0.559
# heart_rate                     0  float64  0.526  95.000     87.837
# resp_rate                      0  float64  1.242  80.000     20.175
# sys_press                      0  float64 -0.096  81.000    121.784
# dias_press                     0  float64 -0.362  81.000     73.105
# mean_press                     0  float64 -0.404  78.000     89.873
# temp                           0  float64  0.103  85.000     36.141
# hemoglobin                     0  float64 -0.342  92.000     11.580
# platelets                      0  float64  0.634  92.000 241643.478
# hematocrit                     0  float64 -0.333  92.000     35.174
# red_cells_count                0  float64 -0.272  92.000      3.743
# hcm                            0  float64 -0.581  91.000     28.712
# rdw                            0  float64  1.179  91.000     14.237
# mcv                            0  float64 -0.640  91.000     87.050
# leukocytes                     0  float64  8.316  92.000  11295.098
# neutrophil                     0  float64  3.228  83.000   6858.289
# lymphocytes                    0  float64  1.008  83.000   1251.030
# basophils                     39  float64  2.455  91.000     21.445
# eosinophils                   22  float64  2.848  92.000    109.788
# monocytes                      0  float64  1.270  90.000    536.728
# crp                            0  float64  4.221  83.000     21.933
# region                         0   object    NaN     NaN        NaN
# state                          0   object    NaN     NaN        NaN
# class                         95    int32  3.464 102.000      0.069
#
#                        std      min        25%        50%        75%  \
# age                 18.864   20.000     38.000     55.000     67.750
# male                 0.499    0.000      0.000      1.000      1.000
# heart_rate          18.547   41.000     75.500     87.000     98.500
# resp_rate            4.096   14.000     18.000     19.500     21.250
# sys_press           25.321   50.000    109.000    120.000    139.000
# dias_press          15.528   35.000     65.000     78.000     80.000
# mean_press          17.731   39.995     81.250     93.000     99.995
# temp                 1.060   32.000     35.700     36.050     36.500
# hemoglobin           2.906    5.800      9.088     12.100     13.825
# platelets       151229.805 7160.000 126950.000 213250.000 352375.000
# hematocrit           8.622   16.900     28.867     36.995     41.975
# red_cells_count      1.155    0.640      2.683      3.980      4.620
# hcm                  2.491   20.500     27.300     28.800     30.800
# rdw                  2.243   10.100     12.800     13.700     15.150
# mcv                  6.560   64.600     83.250     86.900     92.000
# leukocytes       22504.446  920.000   4640.000   7010.000  12272.500
# neutrophil        6721.521  666.000   2934.000   4325.000   9409.250
# lymphocytes        781.045  117.000    645.000   1131.000   1719.500
# basophils           31.126    0.000      0.000      9.000     35.000
# eosinophils        188.895    0.000      1.000     33.500    130.500
# monocytes          337.638    1.012    275.875    511.000    673.000
# crp                 47.897    0.050      2.530      8.700     17.330
# region                 NaN      NaN        NaN        NaN        NaN
# state                  NaN      NaN        NaN        NaN        NaN
# class                0.254    0.000      0.000      0.000      0.000
#
#                        max
# age                 95.000
# male                 1.000
# heart_rate         140.000
# resp_rate           34.000
# sys_press          179.000
# dias_press         109.000
# mean_press         128.313
# temp                39.000
# hemoglobin          18.100
# platelets       645700.000
# hematocrit          54.800
# red_cells_count      6.270
# hcm                 34.900
# rdw                 20.800
# mcv                100.100
# leukocytes      214500.000
# neutrophil       47636.000
# lymphocytes       4290.000
# basophils          181.000
# eosinophils       1005.000
# monocytes         1960.000
# crp                304.650
# region                 NaN
# state                  NaN
# class                1.000

# %%
df_iacov_model_lean['mean_press'] = df_iacov_model_lean.apply(isNullMeanPressure, axis=1)

# %%
#Check mean_press missing after recalculating
column_summaries(df_iacov_model_lean)
# Out:
#                  Missing Values  % missing of Total Values  # Unique Values  \
# age                           0                      0.000               54
# male                          0                      0.000                2
# heart_rate                    7                      6.863               51
# resp_rate                    22                     21.569               16
# sys_press                    21                     20.588               49
# dias_press                   21                     20.588               44
# mean_press                   21                     20.588               50
# temp                         17                     16.667               34
# hemoglobin                   10                      9.804               62
# platelets                    10                      9.804               90
# hematocrit                   10                      9.804               83
# red_cells_count              10                      9.804               77
# hcm                          11                     10.784               57
# rdw                          11                     10.784               48
# mcv                          11                     10.784               77
# leukocytes                   10                      9.804               91
# neutrophil                   19                     18.627               81
# lymphocytes                  19                     18.627               79
# basophils                    11                     10.784               39
# eosinophils                  10                      9.804               59
# monocytes                    12                     11.765               84
# crp                          19                     18.627               81
# region                        0                      0.000                1
# state                         0                      0.000                3
# class                         0                      0.000                2
#
#                  # Values as [0] datatype   skew   count       mean  \
# age                            0  float64  0.072 102.000     53.951
# male                          45  float64 -0.240 102.000      0.559
# heart_rate                     0  float64  0.526  95.000     87.837
# resp_rate                      0  float64  1.242  80.000     20.175
# sys_press                      0  float64 -0.096  81.000    121.784
# dias_press                     0  float64 -0.362  81.000     73.105
# mean_press                     0  float64 -0.366  81.000     89.526
# temp                           0  float64  0.103  85.000     36.141
# hemoglobin                     0  float64 -0.342  92.000     11.580
# platelets                      0  float64  0.634  92.000 241643.478
# hematocrit                     0  float64 -0.333  92.000     35.174
# red_cells_count                0  float64 -0.272  92.000      3.743
# hcm                            0  float64 -0.581  91.000     28.712
# rdw                            0  float64  1.179  91.000     14.237
# mcv                            0  float64 -0.640  91.000     87.050
# leukocytes                     0  float64  8.316  92.000  11295.098
# neutrophil                     0  float64  3.228  83.000   6858.289
# lymphocytes                    0  float64  1.008  83.000   1251.030
# basophils                     39  float64  2.455  91.000     21.445
# eosinophils                   22  float64  2.848  92.000    109.788
# monocytes                      0  float64  1.270  90.000    536.728
# crp                            0  float64  4.221  83.000     21.933
# region                         0   object    NaN     NaN        NaN
# state                          0   object    NaN     NaN        NaN
# class                         95    int32  3.464 102.000      0.069
#
#                        std      min        25%        50%        75%  \
# age                 18.864   20.000     38.000     55.000     67.750
# male                 0.499    0.000      0.000      1.000      1.000
# heart_rate          18.547   41.000     75.500     87.000     98.500
# resp_rate            4.096   14.000     18.000     19.500     21.250
# sys_press           25.321   50.000    109.000    120.000    139.000
# dias_press          15.528   35.000     65.000     78.000     80.000
# mean_press          17.631   39.995     81.000     93.000     99.980
# temp                 1.060   32.000     35.700     36.050     36.500
# hemoglobin           2.906    5.800      9.088     12.100     13.825
# platelets       151229.805 7160.000 126950.000 213250.000 352375.000
# hematocrit           8.622   16.900     28.867     36.995     41.975
# red_cells_count      1.155    0.640      2.683      3.980      4.620
# hcm                  2.491   20.500     27.300     28.800     30.800
# rdw                  2.243   10.100     12.800     13.700     15.150
# mcv                  6.560   64.600     83.250     86.900     92.000
# leukocytes       22504.446  920.000   4640.000   7010.000  12272.500
# neutrophil        6721.521  666.000   2934.000   4325.000   9409.250
# lymphocytes        781.045  117.000    645.000   1131.000   1719.500
# basophils           31.126    0.000      0.000      9.000     35.000
# eosinophils        188.895    0.000      1.000     33.500    130.500
# monocytes          337.638    1.012    275.875    511.000    673.000
# crp                 47.897    0.050      2.530      8.700     17.330
# region                 NaN      NaN        NaN        NaN        NaN
# state                  NaN      NaN        NaN        NaN        NaN
# class                0.254    0.000      0.000      0.000      0.000
#
#                        max
# age                 95.000
# male                 1.000
# heart_rate         140.000
# resp_rate           34.000
# sys_press          179.000
# dias_press         109.000
# mean_press         128.313
# temp                39.000
# hemoglobin          18.100
# platelets       645700.000
# hematocrit          54.800
# red_cells_count      6.270
# hcm                 34.900
# rdw                 20.800
# mcv                100.100
# leukocytes      214500.000
# neutrophil       47636.000
# lymphocytes       4290.000
# basophils          181.000
# eosinophils       1005.000
# monocytes         1960.000
# crp                304.650
# region                 NaN
# state                  NaN
# class                1.000

# %%
X_test_specific['mean_press'] = X_test_specific.apply(isNullMeanPressure, axis=1)

# %%
#column_summaries(X_test_specific)

# %% [markdown]
# ### Put X_test and y_test in separate files

# %%
x_test_specific_name = 'X_test_same_region_absolute_' + X_test_specific.region.iloc[0]  \
                        + '_' + X_test_specific.state.iloc[0]  \
                        + '_' + X_test_specific.city_hospital.iloc[0] +  ".csv"
x_test_specific_name
# Out:
# 'X_test_same_region_absolute_NORDESTE_CE_CEARA_HUWC.csv'

# %%
y_test_specific_name = 'y_death_same_region_absolute_' + X_test_specific.region.iloc[0]  \
                        + '_' + X_test_specific.state.iloc[0]  \
                        + '_' + X_test_specific.city_hospital.iloc[0] +  ".csv"
y_test_specific_name
# Out:
# 'y_death_same_region_absolute_NORDESTE_CE_CEARA_HUWC.csv'

# %%
X_test_specific.to_csv(x_test_specific_name, sep=';')
X_test_specific.shape
# Out:
# (22, 25)

# %%
y_test_specific.to_csv(y_test_specific_name, sep=';')
y_test_specific.shape
# Out:
# (22,)

# %% [markdown]
# ## 2.4) Prepare Experiment

# %%
df_iacov_model_lean.shape
# Out:
# (102, 25)

# %%
df_iacov_model_train = df_iacov_model_lean

# %%
df_iacov_model_train = df_iacov_model_train.drop(['region'],axis=1)
df_iacov_model_train = df_iacov_model_train.drop(['state'],axis=1)
df_iacov_model_train.columns
# Out:
# Index(['age', 'male', 'heart_rate', 'resp_rate', 'sys_press', 'dias_press',
#        'mean_press', 'temp', 'hemoglobin', 'platelets', 'hematocrit',
#        'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes', 'neutrophil',
#        'lymphocytes', 'basophils', 'eosinophils', 'monocytes', 'crp', 'class'],
#       dtype='object')

# %%
df_iacov_model_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102 entries, 2536 to 110
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              102 non-null    float64
#  1   male             102 non-null    float64
#  2   heart_rate       95 non-null     float64
#  3   resp_rate        80 non-null     float64
#  4   sys_press        81 non-null     float64
#  5   dias_press       81 non-null     float64
#  6   mean_press       81 non-null     float64
#  7   temp             85 non-null     float64
#  8   hemoglobin       92 non-null     float64
#  9   platelets        92 non-null     float64
#  10  hematocrit       92 non-null     float64
#  11  red_cells_count  92 non-null     float64
#  12  hcm              91 non-null     float64
#  13  rdw              91 non-null     float64
#  14  mcv              91 non-null     float64
#  15  leukocytes       92 non-null     float64
#  16  neutrophil       83 non-null     float64
#  17  lymphocytes      83 non-null     float64
#  18  basophils        91 non-null     float64
#  19  eosinophils      92 non-null     float64
#  20  monocytes        90 non-null     float64
#  21  crp              83 non-null     float64
#  22  class            102 non-null    int32
# dtypes: float64(22), int32(1)
# memory usage: 18.7 KB

# %%
exp = setup(df_iacov_model_train
            , target='class'
            , categorical_features = ['male']
            , numeric_features = ['crp','basophils','eosinophils','red_cells_count','monocytes','hemoglobin','resp_rate','neutrophil','hematocrit']
            , normalize=True
            #, remove_multicollinearity=True
            ,numeric_imputation='median'
#             ,numeric_imputation='ignore'
            #,multicollinearity_threshold=0.9
            , resample=True
            , resample_method='random_over'
#             , train_size = 1.0 #100pct for training
           )
# Out:
#
# Setup Succesfully Completed!
# <style type="text/css">
# #T_740cc_row4_col1, #T_740cc_row15_col1, #T_740cc_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_740cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_740cc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_740cc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_740cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_740cc_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_740cc_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_740cc_row1_col0" class="data row1 col0" >Target Type</td>
#       <td id="T_740cc_row1_col1" class="data row1 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_740cc_row2_col0" class="data row2 col0" >Label Encoded</td>
#       <td id="T_740cc_row2_col1" class="data row2 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_740cc_row3_col0" class="data row3 col0" >Original Data</td>
#       <td id="T_740cc_row3_col1" class="data row3 col1" >(102, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_740cc_row4_col0" class="data row4 col0" >Missing Values </td>
#       <td id="T_740cc_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_740cc_row5_col0" class="data row5 col0" >Numeric Features </td>
#       <td id="T_740cc_row5_col1" class="data row5 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_740cc_row6_col0" class="data row6 col0" >Categorical Features </td>
#       <td id="T_740cc_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_740cc_row7_col0" class="data row7 col0" >Ordinal Features </td>
#       <td id="T_740cc_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_740cc_row8_col0" class="data row8 col0" >High Cardinality Features </td>
#       <td id="T_740cc_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_740cc_row9_col0" class="data row9 col0" >High Cardinality Method </td>
#       <td id="T_740cc_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_740cc_row10_col0" class="data row10 col0" >Sampled Data</td>
#       <td id="T_740cc_row10_col1" class="data row10 col1" >(163, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_740cc_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_740cc_row11_col1" class="data row11 col1" >(132, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_740cc_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_740cc_row12_col1" class="data row12 col1" >(31, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_740cc_row13_col0" class="data row13 col0" >Numeric Imputer </td>
#       <td id="T_740cc_row13_col1" class="data row13 col1" >median</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_740cc_row14_col0" class="data row14 col0" >Categorical Imputer </td>
#       <td id="T_740cc_row14_col1" class="data row14 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_740cc_row15_col0" class="data row15 col0" >Normalize </td>
#       <td id="T_740cc_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_740cc_row16_col0" class="data row16 col0" >Normalize Method </td>
#       <td id="T_740cc_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_740cc_row17_col0" class="data row17 col0" >Transformation </td>
#       <td id="T_740cc_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_740cc_row18_col0" class="data row18 col0" >Transformation Method </td>
#       <td id="T_740cc_row18_col1" class="data row18 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_740cc_row19_col0" class="data row19 col0" >PCA </td>
#       <td id="T_740cc_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_740cc_row20_col0" class="data row20 col0" >PCA Method </td>
#       <td id="T_740cc_row20_col1" class="data row20 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_740cc_row21_col0" class="data row21 col0" >PCA Components </td>
#       <td id="T_740cc_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_740cc_row22_col0" class="data row22 col0" >Ignore Low Variance </td>
#       <td id="T_740cc_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_740cc_row23_col0" class="data row23 col0" >Combine Rare Levels </td>
#       <td id="T_740cc_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_740cc_row24_col0" class="data row24 col0" >Rare Level Threshold </td>
#       <td id="T_740cc_row24_col1" class="data row24 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_740cc_row25_col0" class="data row25 col0" >Numeric Binning </td>
#       <td id="T_740cc_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_740cc_row26_col0" class="data row26 col0" >Remove Outliers </td>
#       <td id="T_740cc_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_740cc_row27_col0" class="data row27 col0" >Outliers Threshold </td>
#       <td id="T_740cc_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_740cc_row28_col0" class="data row28 col0" >Remove Multicollinearity </td>
#       <td id="T_740cc_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_740cc_row29_col0" class="data row29 col0" >Multicollinearity Threshold </td>
#       <td id="T_740cc_row29_col1" class="data row29 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_740cc_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_740cc_row30_col0" class="data row30 col0" >Clustering </td>
#       <td id="T_740cc_

# %%
X, y, X_train, X_test, y_train, y_test, seed, prep_pipe, _ = exp

# %%
X_train.shape
# Out:
# (132, 22)

# %%
X_test.shape
# Out:
# (31, 22)

# %%
X_test.columns
# Out:
# Index(['age', 'heart_rate', 'resp_rate', 'sys_press', 'dias_press',
#        'mean_press', 'temp', 'hemoglobin', 'platelets', 'hematocrit',
#        'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes', 'neutrophil',
#        'lymphocytes', 'basophils', 'eosinophils', 'monocytes', 'crp',
#        'male_0.0'],
#       dtype='object')

# %%
seed
# Out:
# 42

# %%
# Xtrain.head()

# %% [markdown]
# ### Filtering only 5 pre-selected models

# %%
# print(inspect.getsource(compare_models))

# %%
#Modelos que suportam missing (1) - Modelos pre-selecionados(2)
compare_models(blacklist = ["lr","knn","nb","dt","svm","rbfsvm","gpc","ridge","qda","ada","gbc","lda","et","mlp","rf"] , turbo = False)
# Out:
# <style type="text/css">
# #T_74ab9 th {
#   text-align: left;
# }
# #T_74ab9_row0_col0, #T_74ab9_row0_col9, #T_74ab9_row0_col10, #T_74ab9_row1_col0, #T_74ab9_row1_col1, #T_74ab9_row1_col4, #T_74ab9_row1_col5, #T_74ab9_row1_col6, #T_74ab9_row1_col7, #T_74ab9_row1_col8, #T_74ab9_row1_col10, #T_74ab9_row2_col0, #T_74ab9_row2_col1, #T_74ab9_row2_col4, #T_74ab9_row2_col5, #T_74ab9_row2_col6, #T_74ab9_row2_col7, #T_74ab9_row2_col8, #T_74ab9_row2_col9 {
#   text-align: left;
# }
# #T_74ab9_row0_col1, #T_74ab9_row0_col2, #T_74ab9_row0_col3, #T_74ab9_row0_col4, #T_74ab9_row0_col5, #T_74ab9_row0_col6, #T_74ab9_row0_col7, #T_74ab9_row0_col8, #T_74ab9_row1_col2, #T_74ab9_row1_col3, #T_74ab9_row1_col9, #T_74ab9_row2_col2, #T_74ab9_row2_col3, #T_74ab9_row2_col10 {
#   background-color: yellow;
#   text-align: left;
# }
# </style>
# <table id="T_74ab9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74ab9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_74ab9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_74ab9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_74ab9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_74ab9_level0_col4" class="col_heading level0 col4" >Specificity</th>
#       <th id="T_74ab9_level0_col5" class="col_heading level0 col5" >Prec.</th>
#       <th id="T_74ab9_level0_col6" class="col_heading level0 col6" >F1</th>
#       <th id="T_74ab9_level0_col7" class="col_heading level0 col7" >Kappa</th>
#       <th id="T_74ab9_level0_col8" class="col_heading level0 col8" >Hosmer_lemeshow</th>
#       <th id="T_74ab9_level0_col9" class="col_heading level0 col9" >Spiegelhalter</th>
#       <th id="T_74ab9_level0_col10" class="col_heading level0 col10" >Scaled_brier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74ab9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74ab9_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_74ab9_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_74ab9_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_74ab9_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_74ab9_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_74ab9_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_74ab9_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_74ab9_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_74ab9_row0_col8" class="data row0 col8" >0.999800</td>
#       <td id="T_74ab9_row0_col9" class="data row0 col9" >0.531000</td>
#       <td id="T_74ab9_row0_col10" class="data row0 col10" >0.974800</td>
#     </tr>
#     <tr>
#       <th id="T_74ab9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74ab9_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_74ab9_row1_col1" class="data row1 col1" >0.992300</td>
#       <td id="T_74ab9_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_74ab9_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_74ab9_row1_col4" class="data row1 col4" >0.985700</td>
#       <td id="T_74ab9_row1_col5" class="data row1 col5" >0.985700</td>
#       <td id="T_74ab9_row1_col6" class="data row1 col6" >0.992300</td>
#       <td id="T_74ab9_row1_col7" class="data row1 col7" >0.984700</td>
#       <td id="T_74ab9_row1_col8" class="data row1 col8" >0.998900</td>
#       <td id="T_74ab9_row1_col9" class="data row1 col9" >0.687400</td>
#       <td id="T_74ab9_row1_col10" class="data row1 col10" >0.962900</td>
#     </tr>
#     <tr>
#       <th id="T_74ab9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_74ab9_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_74ab9_row2_col1" class="data row2 col1" >0.992300</td>
#       <td id="T_74ab9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_74ab9_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_74ab9_row2_col4" class="data row2 col4" >0.983300</td>
#       <td id="T_74ab9_row2_col5" class="data row2 col5" >0.987500</td>
#       <td id="T_74ab9_row2_col6" class="data row2 col6" >0.993300</td>
#       <td id="T_74ab9_row2_col7" class="data row2 col7" >0.984300</td>
#       <td id="T_74ab9_row2_col8" class="data row2 col8" >0.999600</td>
#       <td id="T_74ab9_row2_col9" class="data row2 col9" >0.531100</td>
#       <td id="T_74ab9_row2_col10" class="data row2 col10" >0.976000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Tune selected models by AUC (and hyperopt bayesian optimization) to use on test data

# %%
cattuned = tune_model('catboost', optimize='AUC', n_iter=20)
# Out:
#       Accuracy   AUC  Recall  Specificity  Prec.    F1  Kappa  \
# 0        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 1        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 2        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 3        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 4        0.923 1.000   1.000        0.857  0.857 0.923  0.847
# 5        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 6        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 7        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 8        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 9        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# Mean     0.992 1.000   1.000        0.986  0.986 0.992  0.985
# SD       0.023 0.000   0.000        0.043  0.043 0.023  0.046
#
#       Hosmer_lemeshow  Spiegelhalter  Scaled_brier
# 0               1.000          0.523         0.993
# 1               1.000          0.529         0.989
# 2               1.000          0.664         0.998
# 3               1.000          0.523         0.992
# 4               0.991          0.954         0.851
# 5               1.000          0.563         0.990
# 6               1.000          0.476         0.967
# 7               1.000          0.437         0.954
# 8               1.000          0.638         0.995
# 9               1.000          0.513         0.938
# Mean            0.999          0.582         0.967
# SD              0.999          0.582         0.967

# %%
lgbmtuned = tune_model('lightgbm', optimize='AUC', n_iter=20)
# Out:
#       Accuracy   AUC  Recall  Specificity  Prec.    F1  Kappa  \
# 0        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 1        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 2        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 3        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 4        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 5        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 6        0.923 1.000   1.000        0.833  0.875 0.933  0.843
# 7        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 8        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 9        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# Mean     0.992 1.000   1.000        0.983  0.988 0.993  0.984
# SD       0.023 0.000   0.000        0.050  0.037 0.020  0.047
#
#       Hosmer_lemeshow  Spiegelhalter  Scaled_brier
# 0               1.000          0.886         1.000
# 1               1.000          0.781         0.999
# 2               1.000          0.907         1.000
# 3               1.000          0.671         0.996
# 4               1.000          0.825         1.000
# 5               1.000          0.913         1.000
# 6               0.997          0.840         0.892
# 7               1.000          0.669         0.996
# 8               1.000          0.852         1.000
# 9               1.000          0.653         0.937
# Mean            1.000          0.799         0.982
# SD              1.000          0.799         0.982

# %%
xgbtuned = tune_model('xgboost', optimize='AUC', n_iter=20)
# Out:
#       Accuracy   AUC  Recall  Specificity  Prec.    F1  Kappa  \
# 0        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 1        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 2        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 3        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 4        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 5        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 6        0.923 1.000   1.000        0.833  0.875 0.933  0.843
# 7        0.923 1.000   1.000        0.833  0.875 0.933  0.843
# 8        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# 9        1.000 1.000   1.000        1.000  1.000 1.000  1.000
# Mean     0.985 1.000   1.000        0.967  0.975 0.987  0.969
# SD       0.031 0.000   0.000        0.067  0.050 0.027  0.063
#
#       Hosmer_lemeshow  Spiegelhalter  Scaled_brier
# 0               0.999          0.355         0.976
# 1               0.999          0.372         0.983
# 2               1.000          0.408         0.987
# 3               0.996          0.276         0.950
# 4               0.999          0.344         0.973
# 5               1.000          0.431         0.988
# 6               0.990          0.647         0.856
# 7               0.996          0.316         0.891
# 8               1.000          0.386         0.966
# 9               0.999          0.368         0.923
# Mean            0.998          0.390         0.949
# SD              0.998          0.390         0.949

# %% [markdown]
# ### Select best algorithm based on test data AUC

# %%
preds_cat = predict_model(cattuned)
# Out:
#                  Model  Accuracy   AUC  Recall  Specificity  Prec.    F1  \
# 0  CatBoost Classifier     0.903 0.776   0.000        0.966  0.000 0.000
#
#    Kappa  Hosmer_lemeshow  Spiegelhalter  Scaled_brier
# 0 -0.045            0.361          0.594        -0.213

# %%
preds_lgb = predict_model(lgbmtuned)
# Out:
#                              Model  Accuracy   AUC  Recall  Specificity  \
# 0  Light Gradient Boosting Machine     0.871 0.931   0.000        0.931
#
#    Prec.    F1  Kappa  Hosmer_lemeshow  Spiegelhalter  Scaled_brier
# 0  0.000 0.000 -0.069            0.687          0.000        -0.568

# %%
preds_xgb = predict_model(xgbtuned)
# Out:
#                        Model  Accuracy   AUC  Recall  Specificity  Prec.  \
# 0  Extreme Gradient Boosting     0.903 0.948   0.000        0.966  0.000
#
#      F1  Kappa  Hosmer_lemeshow  Spiegelhalter  Scaled_brier
# 0 0.000 -0.045            0.968          0.370         0.108

# %%
# Put in PREDS the best algorithm chosen in the previous lines: preds_cat OR preds_lgb OR preds_xgb
#preds = preds_cat
#preds = preds_lgb
preds = preds_xgb

# %% [markdown]
# ### Best model

# %%
npv(y_test, preds['Label'])
# Out:
# 0.9333333333333333

# %%
#ROC AUC (INTERVALO)
["{0:0.2f}".format(i) for i in AUC_CI(y_test, preds['Score'].values)]
# Out:
# ['0.87', '1.00']

# %%
import MLFlow_Utils
binary_classification_metrics(y_test, preds["Label"], preds["Score"])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[71], line 2
#       1 import MLFlow_Utils
# ----> 2 binary_classification_metrics(y_test, preds["Label"], preds["Score"])
#
# File ~\OneDrive\Documents\carine\A_POS_DOC\iacovpy10\MLFlow_Utils.py:584, in binary_classification_metrics(ground_truth, prediction, prediction_proba, show_results)
#     566 warnings.filterwarnings("ignore")
#     568 fprate, tprate, thresholds = roc_curve(ground_truth, prediction_proba, pos_label=1)
#     570 monitor = pd.DataFrame(
#     571     [
#     572         ["Ground Truth Prevalence", ". . . ", prevalence(ground_truth)],
#     573         ["Test set Prevalence", ". . . ", prevalence(prediction)],
#     574         ["True positive rate (recall)", ". . . ", tpr(ground_truth, prediction)],
#     575         ["False positive rate", ". . . ", fpr(ground_truth, prediction)],
#     576         ["Positive predictive value (precision)", ". . . ", ppv(ground_truth, prediction)],
#     577         ["True negative rate (specificity)", ". . . ", tnr(ground_truth, prediction)],
#     578         ["False negative rate", ". . . ", fnr(ground_truth, prediction)],
#     579         ["Negative predictive value", ". . . ", npv(ground_truth, prediction)],
#     580         ["Positive likelihood ratio (bigger is better)", ". . . ", plr(ground_truth, prediction)],
#     581         ["Negative likelihood ratio (smaller is better)", ". . . ", nlr(ground_truth, prediction)],
#     582         ["Diagnostic odds ratio", ". . . ", dor(ground_truth, prediction)],
#     583         ["Accuracy", ". . . ", accuracy(ground_truth, prediction)],
# --> 584         ["F1 score", ". . . ", f1_score(ground_truth, prediction)],
#     585         ["Accuracy", ". . . ", accuracy(ground_truth, prediction)],
#     586         ["ROC AUC", ". . . ", auc(fprate, tprate)],
#     587         ["ROC AUC (95% CI)", ". . . ", ["{0:0.2f}".format(i) for i in AUC_CI(ground_truth, prediction_proba._values)]],
#     588         ["Scaled Brier Score", ". . . ", scaled_brier_score(ground_truth, prediction_proba)],
#     589         ["Hosmer_Lemeshow p-value", ". . . ", hosmer_lemeshow(ground_truth, prediction_proba)],
#     590         ["Spiegelhalter p-value", ". . . ", spiegelhalter(ground_truth, prediction_proba)],
#     591
#     592     ],
#     593     columns=["", " ", "   "],
#     594 ).set_index("")
#     595 if show_results:
#     596     display(monitor)
#
# File ~\OneDrive\Documents\carine\A_POS_DOC\iacovpy10\MLFlow_Utils.py:427, in f1_score(ground_truth, predicted)
#     422 def f1_score(ground_truth, predicted):
#     423     """
#     424     This function measures the f1 score
#     425     (also called "balanced f score")
#     426     """
# --> 427     return (2 / ((1 / true_positive_rate(ground_truth, predicted)) +
#     428                  (1 / positive_predictive_value(ground_truth, predicted))))
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ### Understand best algorithm features and results
# #### Run INTERPRETE_MODEL only for the best algorithm chosen in the previous line¶

# %%
#evaluate_model(lgbmtuned)

# %%
#interpret_model(cattuned)
#interpret_model(lgbmtuned)
interpret_model(xgbtuned)

# %%
#plot_model(lgbmtuned, plot='ktops')

# %% [markdown]
# ### 2.3.1) Build a model with all data
# #### Run FINALIZE MODEL only for the best algorithm chosen in the previous lines

# %%
#final_model = finalize_model(cattuned)
#final_model = finalize_model(lgbmtuned)
final_model = finalize_model(xgbtuned)

# %%
str(final_model.__class__.__name__)
# Out:
# 'XGBClassifier'

# %%
final_model_name = str(final_model.__class__.__name__) + '_same_region_abs_number_' \
                    + X_test_specific.region.iloc[0]  \
                    + '_' + X_test_specific.state.iloc[0]  \
                    + '_' + X_test_specific.city_hospital.iloc[0]
final_model_name
# Out:
# 'XGBClassifier_same_region_abs_number_NORDESTE_CE_CEARA_HUWC'

# %%
save_model(final_model, final_model_name ,verbose=True)
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
#final_model.get_all_params()
final_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.55, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.295, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=1.0, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=275, n_jobs=-2,
#               num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# # Use the saved model to predict on specific hospital

# %%
import pickle
import joblib

#Carrego o modelo unico
print('loaded: ' + final_model_name)

same_region_abs_number_model_pkl = final_model_name + ".pkl"
prep_pipe_same_region_abs_number, same_region_abs_number_model = joblib.load(same_region_abs_number_model_pkl)
# Out:
# loaded: XGBClassifier_same_region_abs_number_NORDESTE_CE_CEARA_HUWC

# %%
same_region_abs_number_model.__class__.__name__
# Out:
# 'XGBClassifier'

# %%
x_test_specific_name
# Out:
# 'X_test_same_region_absolute_NORDESTE_CE_CEARA_HUWC.csv'

# %%
#Carrego o X_test do modelo único
X_test_single = pd.read_csv(x_test_specific_name, delimiter=";",index_col=0)
X_test_single.shape
# Out:
# (22, 25)

# %%
X_test_single.columns
# Out:
# Index(['city_hospital', 'age', 'male', 'heart_rate', 'resp_rate', 'sys_press',
#        'dias_press', 'mean_press', 'temp', 'hemoglobin', 'platelets',
#        'hematocrit', 'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes',
#        'neutrophil', 'lymphocytes', 'basophils', 'eosinophils', 'monocytes',
#        'crp', 'region', 'state'],
#       dtype='object')

# %%
#Carrego o Y_test do modelo único
y_test_single = pd.read_csv(y_test_specific_name, delimiter=";",index_col=0)
y_test_single = y_test_single["mv"]
y_test_single.shape
# Out:
# (22,)

# %%
pd.set_option('display.max_columns', None)
X_test_single.head()
# Out:
#     city_hospital    age  male  heart_rate  resp_rate  sys_press  dias_press  \
# 98     CEARA_HUWC 58.000 1.000      66.000     17.000    120.000      70.000
# 113    CEARA_HUWC 60.000 0.000      87.000     16.000    118.000      69.000
# 103    CEARA_HUWC 64.000 1.000      88.000     23.000     92.000      60.000
# 53     CEARA_HUWC 71.000 1.000      75.000     16.000     81.000      54.000
# 84     CEARA_HUWC 69.000 1.000      88.000     28.000    131.000      55.000
#
#      mean_press   temp  hemoglobin  platelets  hematocrit  red_cells_count  \
# 98       87.000 36.100       9.800 157300.000      29.200            3.380
# 113      85.000 35.000       5.000 826600.000      16.600            2.280
# 103      71.000 35.600       7.900 149600.000      23.200            2.240
# 53       63.000 35.500       7.200  98550.000      22.670            2.500
# 84       80.000 35.200      10.900 160000.000      33.100            3.720
#
#        hcm    rdw     mcv  leukocytes  neutrophil  lymphocytes  basophils  \
# 98  28.900 12.600  86.500    2460.000    1057.000      762.000      0.000
# 113 22.100 17.600  72.900   11970.000    7608.000     2958.000     77.000
# 103 35.600 17.400 103.600   11110.000   10110.000      556.000      0.000
# 53  29.100 17.000  90.700    9285.000    6707.000     1418.000     40.000
# 84  29.500 12.200  89.100   23720.000   23008.000      238.000      0.000
#
#      eosinophils  monocytes    crp    region state
# 98       123.000    516.000  2.660  NORDESTE    CE
# 113      161.000   1166.000    NaN  NORDESTE    CE
# 103        0.000    444.000  9.610  NORDESTE    CE
# 53       800.000    317.000 13.380  NORDESTE    CE
# 84         0.000    474.000 14.020  NORDESTE    CE

# %%
X_test_single["class"] = y_test_single

# %%
X_test_single.columns
# Out:
# Index(['city_hospital', 'age', 'male', 'heart_rate', 'resp_rate', 'sys_press',
#        'dias_press', 'mean_press', 'temp', 'hemoglobin', 'platelets',
#        'hematocrit', 'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes',
#        'neutrophil', 'lymphocytes', 'basophils', 'eosinophils', 'monocytes',
#        'crp', 'region', 'state', 'class'],
#       dtype='object')

# %%
X_test_single = X_test_single.drop(['city_hospital'],axis=1)
X_test_single = X_test_single.drop(['region'],axis=1)
X_test_single = X_test_single.drop(['state'],axis=1)

# %%
X_test_single_transformed = prep_pipe_same_region_abs_number.fit_transform(X_test_single)
X_test_single_transformed.head()
# Out:
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                    Data Type
# age                  Numeric
# male             Categorical
# heart_rate           Numeric
# resp_rate            Numeric
# sys_press            Numeric
# dias_press           Numeric
# mean_press           Numeric
# temp                 Numeric
# hemoglobin           Numeric
# platelets            Numeric
# hematocrit           Numeric
# red_cells_count      Numeric
# hcm                  Numeric
# rdw                  Numeric
# mcv                  Numeric
# leukocytes           Numeric
# neutrophil           Numeric
# lymphocytes          Numeric
# basophils            Numeric
# eosinophils          Numeric
# monocytes            Numeric
# crp                  Numeric
# class                  Label
#      class    age  heart_rate  resp_rate  sys_press  dias_press  mean_press  \
# 98       0 -0.187      -1.411     -0.301     -0.084      -0.322      -0.208
# 113      0 -0.037       0.446     -0.546     -0.156      -0.380      -0.307
# 103      0  0.262       0.535      1.170     -1.084      -0.902      -1.002
# 53       1  0.786      -0.615     -0.546     -1.477      -1.250      -1.400
# 84       1  0.637       0.535      2.396      0.308      -1.192      -0.555
#
#       temp  hemoglobin  platelets  hematocrit  red_cells_count    hcm    rdw  \
# 98   0.090       0.079     -0.333      -0.055           -0.040  0.087 -0.697
# 113 -1.054      -2.372      3.814      -2.295           -1.628 -1.855  0.881
# 103 -0.430      -0.891     -0.380      -1.121           -1.686  2.000  0.818
# 53  -0.534      -1.249     -0.697      -1.215           -1.311  0.144  0.691
# 84  -0.846       0.641     -0.316       0.639            0.451  0.258 -0.823
#
#        mcv  leukocytes  neutrophil  lymphocytes  basophils  eosinophils  \
# 98  -0.089      -1.221      -1.066       -0.744     -0.918       -0.240
# 113 -1.658       0.913       0.397        2.264      1.091       -0.099
# 103  1.883       0.720       0.955       -1.026     -0.918       -0.697
# 53   0.395       0.310       0.196        0.155      0.126        2.273
# 84   0.211       3.549       3.836       -1.462     -0.918       -0.697
#
#      monocytes    crp  male_1.0
# 98      -0.099 -1.058     1.000
# 113      2.300  0.022     0.000
# 103     -0.365  0.330     1.000
# 53      -0.834  1.082     1.000
# 84      -0.254  1.210     1.000

# %%
X_test_single_transformed = X_test_single_transformed.drop(['class'],axis=1)

# %%
X_test_single_transformed.shape
# Out:
# (22, 22)

# %%
X_test.columns
# Out:
# Index(['age', 'heart_rate', 'resp_rate', 'sys_press', 'dias_press',
#        'mean_press', 'temp', 'hemoglobin', 'platelets', 'hematocrit',
#        'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes', 'neutrophil',
#        'lymphocytes', 'basophils', 'eosinophils', 'monocytes', 'crp',
#        'male_0.0'],
#       dtype='object')

# %%
X_test_single_transformed.columns
# Out:
# Index(['age', 'heart_rate', 'resp_rate', 'sys_press', 'dias_press',
#        'mean_press', 'temp', 'hemoglobin', 'platelets', 'hematocrit',
#        'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes', 'neutrophil',
#        'lymphocytes', 'basophils', 'eosinophils', 'monocytes', 'crp',
#        'male_1.0'],
#       dtype='object')

# %%
#Show distinct columns
distinct_columns = X_test[X_test.columns.difference(X_test_single_transformed.columns)].columns.tolist()
distinct_columns
# Out:
# ['male_0.0']

# %% [markdown]
# ### Add missing columns to some hospitals that didn't collect all columns
# e.g. HC_USP (missing: red_cells_count and eosinophils)

# %%
for column in distinct_columns:
    if(column=='male_0.0'):
        X_test_single_transformed['male_0.0'] = X_test_single_transformed['male_1.0'].apply(lambda x: 1.0 if x==0.0 else 0.0)
        X_test_single_transformed = X_test_single_transformed.drop('male_1.0', axis=1)
    elif(column=='male_1.0'):
        X_test_single_transformed['male_1.0'] = X_test_single_transformed['male_0.0'].apply(lambda x: 1.0 if x==0.0 else 0.0)
        X_test_single_transformed = X_test_single_transformed.drop('male_0.0', axis=1)
    else:
        X_test_single_transformed[column]=np.NaN

# %%
# X_test_single_transformed['male_1.0'] = X_test_single_transformed['male_0.0'].apply(lambda x: 1.0 if x==0.0 else 0.0)

# %%
X_test_single_transformed.columns
# Out:
# Index(['age', 'heart_rate', 'resp_rate', 'sys_press', 'dias_press',
#        'mean_press', 'temp', 'hemoglobin', 'platelets', 'hematocrit',
#        'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes', 'neutrophil',
#        'lymphocytes', 'basophils', 'eosinophils', 'monocytes', 'crp',
#        'male_0.0'],
#       dtype='object')

# %%
X_test_single_transformed.shape
# Out:
# (22, 22)

# %%
X_test.columns
# Out:
# Index(['age', 'heart_rate', 'resp_rate', 'sys_press', 'dias_press',
#        'mean_press', 'temp', 'hemoglobin', 'platelets', 'hematocrit',
#        'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes', 'neutrophil',
#        'lymphocytes', 'basophils', 'eosinophils', 'monocytes', 'crp',
#        'male_0.0'],
#       dtype='object')

# %%
X_test_single_transformed.columns
# Out:
# Index(['age', 'heart_rate', 'resp_rate', 'sys_press', 'dias_press',
#        'mean_press', 'temp', 'hemoglobin', 'platelets', 'hematocrit',
#        'red_cells_count', 'hcm', 'rdw', 'mcv', 'leukocytes', 'neutrophil',
#        'lymphocytes', 'basophils', 'eosinophils', 'monocytes', 'crp',
#        'male_0.0'],
#       dtype='object')

# %% [markdown]
# **Reorder columns**

# %%
# X_test_single_transformed['male_1.0'] = X_test_single_transformed['male_0.0'].apply(lambda x: 1.0 if x==0.0 else 0.0)

# %%
# Reorder columns
X_test_single_transformed = X_test_single_transformed[X_test.columns]
X_test_single_transformed.shape
# Out:
# (22, 22)

# %%
X_test_same_region_absolute_vs_one_name = 'X_test_same_region_absolute_vs_one_transformed_' + X_test_specific.region.iloc[0]  \
                        + '_' + X_test_specific.state.iloc[0]  \
                        + '_' + X_test_specific.city_hospital.iloc[0] +  ".csv"
X_test_same_region_absolute_vs_one_name
# Out:
# 'X_test_same_region_absolute_vs_one_transformed_NORDESTE_CE_CEARA_HUWC.csv'

# %%
X_test_single_transformed.to_csv(X_test_same_region_absolute_vs_one_name, sep=';')

# %%
#Vejo a curva ROC do modelo INDIVIDUAL e confirmo o valor da AUC
from sklearn.metrics import (roc_curve,auc)

y_pred_prob1 = same_region_abs_number_model.predict_proba(X_test_single_transformed)[:,1]
fpr1 , tpr1, thresholds1 = roc_curve(y_test_single, y_pred_prob1)

auc_ind = auc(fpr1, tpr1)
print(auc_ind)
plt.plot(fpr1, tpr1, label= "Single Model - best model - AUC " +  str(auc_ind), color="yellow")

# %%
y_pred_prob1.shape

# %%
y_pred = same_region_abs_number_model.predict(X_test_single_transformed)

# %%
import MLFlow_Utils
binary_classification_metrics(y_test_single, y_pred, pd.Series(y_pred_prob1))

# %%
fprate, tprate, thresholds = roc_curve(y_test_single, y_pred_prob1, pos_label=1)
auc(fprate, tprate)

# %%
#ROC_AUC
["{0:0.2f}".format(i) for i in AUC_CI(y_test_single, y_pred_prob1)]

# %%
#recall
tpr(y_test_single, y_pred)

# %%
#specificidade
tnr(y_test_single, pd.Series(y_pred))

# %%
#accuracy
accuracy(y_test_single, y_pred)

# %%
ppv(y_test_single, y_pred)

# %%
npv(y_test_single, y_pred)

# %% [markdown]
# # End of File
